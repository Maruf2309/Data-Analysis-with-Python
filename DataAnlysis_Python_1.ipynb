# %% [markdown]
# # Topic - Data Analysis_Python

# %% [markdown]
# - import data
# - head & tail
# - df.shape (To know number of rows & columns)
# - columns name
# - Finding Unique values in a column or by columns
# - Uninue
# - Null & Isnull
# - Null count
# - Filtering
# - Rename Column
# - Statistical Insights
# - Find Str format data
# - Conditions
# - Group by

# %%
import pandas as pd

# %%
df = pd.read_csv('weather_data.csv')
df
# Out:
#            day      city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  \
# 0    01-Nov-22  New York      22              19  Rainy               -12
# 1    02-Nov-22  New York      45              15  Sunny               -18
# 2    03-Nov-22  New York      40              16   Snow                -2
# 3    04-Nov-22  New York      41              16   Snow               -11
# 4    05-Nov-22    Mumbai      29               7  Rainy                -9
# ..         ...       ...     ...             ...    ...               ...
# 582  05-Jul-24    Mumbai      42              30  Rainy               -10
# 583  06-Jul-24    Mumbai      21              24  Rainy               -16
# 584  07-Jul-24    Mumbai      32               8  Rainy                -5
# 585  08-Jul-24    Mumbai      22              11  Rainy               -17
# 586  09-Jul-24    Mumbai      19              18  Rainy                -3
#
#      Rel Hum %  Visibility_km  Press_kPa
# ...

# %%
df.head(5)
# Out:
#          day      city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  \
# 0  01-Nov-22  New York      22              19  Rainy               -12
# 1  02-Nov-22  New York      45              15  Sunny               -18
# 2  03-Nov-22  New York      40              16   Snow                -2
# 3  04-Nov-22  New York      41              16   Snow               -11
# 4  05-Nov-22    Mumbai      29               7  Rainy                -9
#
#    Rel Hum %  Visibility_km  Press_kPa
# 0         49             28         83
# 1         82             22        104
# 2         56             20         81
# 3         84             10        100
# 4         60             24         97

# %%
df.tail(5)
# Out:
#            day    city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  \
# 582  05-Jul-24  Mumbai      42              30  Rainy               -10
# 583  06-Jul-24  Mumbai      21              24  Rainy               -16
# 584  07-Jul-24  Mumbai      32               8  Rainy                -5
# 585  08-Jul-24  Mumbai      22              11  Rainy               -17
# 586  09-Jul-24  Mumbai      19              18  Rainy                -3
#
#      Rel Hum %  Visibility_km  Press_kPa
# 582         74             22         80
# 583         79             14        108
# 584         62             20        112
# 585         25             11        100
# 586         70             16         98

# %%
df.shape
# Out:
# (587, 9)

# %%
df.columns
# Out:
# Index(['day', 'city', 'Temp_C', 'windspeed_km/h', 'event', 'Dew Point Temp_C',
#        'Rel Hum %', 'Visibility_km', 'Press_kPa'],
#       dtype='object')

# %%
df.dtypes
# Out:
# day                 object
# city                object
# Temp_C               int64
# windspeed_km/h       int64
# event               object
# Dew Point Temp_C     int64
# Rel Hum %            int64
# Visibility_km        int64
# Press_kPa            int64
# dtype: object

# %% [markdown]
# # UNIQUE

# %%
df['event'].unique ()
# syntax : table['col name'].unique()
# Out:
# array(['Rainy', 'Sunny', 'Snow'], dtype=object)

# %% [markdown]
# ### Unique values by columns

# %%
df.nunique()   # n unique
# Out:
# day                 587
# city                  3
# Temp_C               31
# windspeed_km/h       26
# event                 3
# Dew Point Temp_C     21
# Rel Hum %            63
# Visibility_km        22
# Press_kPa            38
# dtype: int64

# %% [markdown]
# # NULL & COUNT

# %%
df.isnull()  # Show Null, if True that is null, otherwise not null, it return bolean
# Out:
#        day   city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  Rel Hum %  \
# 0    False  False   False           False  False             False      False
# 1    False  False   False           False  False             False      False
# 2    False  False   False           False  False             False      False
# 3    False  False   False           False  False             False      False
# 4    False  False   False           False  False             False      False
# ..     ...    ...     ...             ...    ...               ...        ...
# 582  False  False   False           False  False             False      False
# 583  False  False   False           False  False             False      False
# 584  False  False   False           False  False             False      False
# 585  False  False   False           False  False             False      False
# 586  False  False   False           False  False             False      False
#
#      Visibility_km  Press_kPa
# ...

# %%
df.isnull().sum()  # Null count by columns
# Out:
# day                 0
# city                0
# Temp_C              0
# windspeed_km/h      0
# event               0
# Dew Point Temp_C    0
# Rel Hum %           0
# Visibility_km       0
# Press_kPa           0
# dtype: int64

# %%
df.count () # Non null value counts by colums
# Out:
# day                 587
# city                587
# Temp_C              587
# windspeed_km/h      587
# event               587
# Dew Point Temp_C    587
# Rel Hum %           587
# Visibility_km       587
# Press_kPa           587
# dtype: int64

# %% [markdown]
# ### Unique values with counts

# %%
df['event'].value_counts()  # Works like excel countif function, Unique counts by column values
# Out:
# Rainy    356
# Snow     124
# Sunny    107
# Name: event, dtype: int64

# %%
df.info()  # Basic Information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   day               587 non-null    object
#  1   city              587 non-null    object
#  2   Temp_C            587 non-null    int64
#  3   windspeed_km/h    587 non-null    int64
#  4   event             587 non-null    object
#  5   Dew Point Temp_C  587 non-null    int64
#  6   Rel Hum %         587 non-null    int64
#  7   Visibility_km     587 non-null    int64
#  8   Press_kPa         587 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 41.4+ KB

# %% [markdown]
# # Data Analysis

# %%
df.head(2)
# Out:
#          day      city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  \
# 0  01-Nov-22  New York      22              19  Rainy               -12
# 1  02-Nov-22  New York      45              15  Sunny               -18
#
#    Rel Hum %  Visibility_km  Press_kPa
# 0         49             28         83
# 1         82             22        104

# %% [markdown]
# # Filtering Data or Access the selective data

# %%
df['event'].unique()
# Out:
# array(['Rainy', 'Sunny', 'Snow'], dtype=object)

# %%
df['event']=='Rainy'  # Access Rainy data from 'event' col
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 582     True
# 583     True
# 584     True
# 585     True
# 586     True
# Name: event, Length: 587, dtype: bool

# %%
df[df['event']=='Rainy']  # Rainy data in data fram by using []
# Out:
#            day      city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  \
# 0    01-Nov-22  New York      22              19  Rainy               -12
# 4    05-Nov-22    Mumbai      29               7  Rainy                -9
# 5    06-Nov-22    Mumbai      36              18  Rainy               -17
# 8    09-Nov-22     Paris      34              26  Rainy               -17
# 9    10-Nov-22     Paris      30              12  Rainy                -2
# ..         ...       ...     ...             ...    ...               ...
# 582  05-Jul-24    Mumbai      42              30  Rainy               -10
# 583  06-Jul-24    Mumbai      21              24  Rainy               -16
# 584  07-Jul-24    Mumbai      32               8  Rainy                -5
# 585  08-Jul-24    Mumbai      22              11  Rainy               -17
# 586  09-Jul-24    Mumbai      19              18  Rainy                -3
#
#      Rel Hum %  Visibility_km  Press_kPa
# ...

# %%
df[df['event']=='Sunny']  # Access Sunny
# Out:
#            day      city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  \
# 1    02-Nov-22  New York      45              15  Sunny               -18
# 6    07-Nov-22    Mumbai      48              12  Sunny                -3
# 7    08-Nov-22    Mumbai      30              10  Sunny                -9
# 13   14-Nov-22  New York      39               9  Sunny                -9
# 18   19-Nov-22    Mumbai      47              18  Sunny                -5
# ..         ...       ...     ...             ...    ...               ...
# 379  15-Dec-23    Mumbai      34              22  Sunny                -6
# 384  20-Dec-23     Paris      38              20  Sunny               -16
# 385  21-Dec-23  New York      46              29  Sunny               -16
# 388  24-Dec-23    Mumbai      43              26  Sunny               -15
# 389  25-Dec-23    Mumbai      34              24  Sunny               -18
#
#      Rel Hum %  Visibility_km  Press_kPa
# ...

# %%
df[df['event']=='Snow']
# Out:
#            day      city  Temp_C  windspeed_km/h event  Dew Point Temp_C  \
# 2    03-Nov-22  New York      40              16  Snow                -2
# 3    04-Nov-22  New York      41              16  Snow               -11
# 10   11-Nov-22     Paris      33              32  Snow                -5
# 11   12-Nov-22     Paris      21              11  Snow               -13
# 12   13-Nov-22     Paris      41              27  Snow               -18
# ..         ...       ...     ...             ...   ...               ...
# 365  01-Dec-23     Paris      37              31  Snow               -18
# 372  08-Dec-23    Mumbai      44              20  Snow               -11
# 374  10-Dec-23  New York      28              20  Snow                -8
# 375  11-Dec-23  New York      39              17  Snow               -14
# 382  18-Dec-23     Paris      23              12  Snow               -20
#
#      Rel Hum %  Visibility_km  Press_kPa
# 2           56             20         81
# ...

# %% [markdown]
# ## Access by city

# %%
df['city'].unique()
# Out:
# array(['New York', 'Mumbai', 'Paris'], dtype=object)

# %%
df[df['city']=='New York']
# Out:
#            day      city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  \
# 0    01-Nov-22  New York      22              19  Rainy               -12
# 1    02-Nov-22  New York      45              15  Sunny               -18
# 2    03-Nov-22  New York      40              16   Snow                -2
# 3    04-Nov-22  New York      41              16   Snow               -11
# 13   14-Nov-22  New York      39               9  Sunny                -9
# ..         ...       ...     ...             ...    ...               ...
# 371  07-Dec-23  New York      28              32  Rainy                -5
# 374  10-Dec-23  New York      28              20   Snow                -8
# 375  11-Dec-23  New York      39              17   Snow               -14
# 385  21-Dec-23  New York      46              29  Sunny               -16
# 386  22-Dec-23  New York      18              22  Rainy                -2
#
#      Rel Hum %  Visibility_km  Press_kPa
# ...

# %%
df[df['city']=='Mumbai']
# Out:
#            day    city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  \
# 4    05-Nov-22  Mumbai      29               7  Rainy                -9
# 5    06-Nov-22  Mumbai      36              18  Rainy               -17
# 6    07-Nov-22  Mumbai      48              12  Sunny                -3
# 7    08-Nov-22  Mumbai      30              10  Sunny                -9
# 15   16-Nov-22  Mumbai      25              31   Snow                -2
# ..         ...     ...     ...             ...    ...               ...
# 582  05-Jul-24  Mumbai      42              30  Rainy               -10
# 583  06-Jul-24  Mumbai      21              24  Rainy               -16
# 584  07-Jul-24  Mumbai      32               8  Rainy                -5
# 585  08-Jul-24  Mumbai      22              11  Rainy               -17
# 586  09-Jul-24  Mumbai      19              18  Rainy                -3
#
#      Rel Hum %  Visibility_km  Press_kPa
# 4           60             24         97
# ...

# %%
df[df['city']=='Paris']
# Out:
#            day   city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  \
# 8    09-Nov-22  Paris      34              26  Rainy               -17
# 9    10-Nov-22  Paris      30              12  Rainy                -2
# 10   11-Nov-22  Paris      33              32   Snow                -5
# 11   12-Nov-22  Paris      21              11   Snow               -13
# 12   13-Nov-22  Paris      41              27   Snow               -18
# ..         ...    ...     ...             ...    ...               ...
# 380  16-Dec-23  Paris      47              15  Rainy                -3
# 381  17-Dec-23  Paris      43              31  Rainy                -8
# 382  18-Dec-23  Paris      23              12   Snow               -20
# 383  19-Dec-23  Paris      37              16  Rainy               -15
# 384  20-Dec-23  Paris      38              20  Sunny               -16
#
#      Rel Hum %  Visibility_km  Press_kPa
# 8           56              9         94
# ...

# %% [markdown]
# ### Access data as per windspeed 7 km/h

# %%
df['windspeed_km/h']==7
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 582    False
# 583    False
# 584    False
# 585    False
# 586    False
# Name: windspeed_km/h, Length: 587, dtype: bool

# %%
df[df['windspeed_km/h']==7]   # Return those data, which windspeed 7 km/h
# Out:
#            day      city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  \
# 4    05-Nov-22    Mumbai      29               7  Rainy                -9
# 16   17-Nov-22    Mumbai      43               7  Rainy                -4
# 23   24-Nov-22    Mumbai      44               7   Snow               -16
# 66   06-Jan-23    Mumbai      24               7   Snow                -8
# 93   02-Feb-23    Mumbai      21               7   Snow               -12
# 125  05-Apr-23  New York      18               7   Snow               -11
# 127  07-Apr-23    Mumbai      35               7  Rainy                -2
# 144  24-Apr-23    Mumbai      31               7  Rainy               -22
# 175  25-May-23  New York      29               7  Rainy                -2
# 252  10-Aug-23    Mumbai      20               7  Rainy               -17
# 265  23-Aug-23    Mumbai      45               7  Sunny                -4
# 270  28-Aug-23     Paris      43               7  Sunny                -5
# ...

# %%
df[df['windspeed_km/h']==10] # Return those data, which windspeed 10 km/h
# Out:
#            day      city  Temp_C  windspeed_km/h  event  Dew Point Temp_C  \
# 7    08-Nov-22    Mumbai      30              10  Sunny                -9
# 32   03-Dec-22    Mumbai      42              10  Sunny               -18
# 36   07-Dec-22    Mumbai      43              10   Snow                -3
# 137  17-Apr-23     Paris      44              10  Sunny                -2
# 185  04-Jun-23     Paris      20              10  Sunny               -20
# 191  10-Jun-23    Mumbai      48              10  Rainy               -20
# 211  30-Jun-23    Mumbai      25              10  Rainy               -10
# 219  08-Jul-23  New York      46              10  Sunny                -2
# 253  11-Aug-23     Paris      18              10  Sunny               -16
# 306  03-Oct-23    Mumbai      41              10  Rainy                -5
# 317  14-Oct-23     Paris      42              10  Rainy                -4
# 332  29-Oct-23     Paris      22              10   Snow                -6
# ...

# %%
df[df['windspeed_km/h']>10]  # Find values greather than 10
# Out:
#            day      city  Temp_C  windspeed_km/h Weather  Dew Point Temp_C  \
# 0    01-Nov-22  New York      22              19   Rainy               -12
# 1    02-Nov-22  New York      45              15   Sunny               -18
# 2    03-Nov-22  New York      40              16    Snow                -2
# 3    04-Nov-22  New York      41              16    Snow               -11
# 5    06-Nov-22    Mumbai      36              18   Rainy               -17
# ..         ...       ...     ...             ...     ...               ...
# 581  04-Jul-24    Mumbai      36              22   Rainy               -17
# 582  05-Jul-24    Mumbai      42              30   Rainy               -10
# 583  06-Jul-24    Mumbai      21              24   Rainy               -16
# 585  08-Jul-24    Mumbai      22              11   Rainy               -17
# 586  09-Jul-24    Mumbai      19              18   Rainy                -3
#
#      Rel Hum %  Visibility_km  Press_kPa
# ...

# %% [markdown]
# # Rename Column & Inplace

# %%
df.rename(columns={'event':'Weather'})  # Col name 'event' renamed to 'wether' not effective to original df without inplace true
# Out:
#            day      city  Temp_C  windspeed_km/h Weather  Dew Point Temp_C  \
# 0    01-Nov-22  New York      22              19   Rainy               -12
# 1    02-Nov-22  New York      45              15   Sunny               -18
# 2    03-Nov-22  New York      40              16    Snow                -2
# 3    04-Nov-22  New York      41              16    Snow               -11
# 4    05-Nov-22    Mumbai      29               7   Rainy                -9
# ..         ...       ...     ...             ...     ...               ...
# 582  05-Jul-24    Mumbai      42              30   Rainy               -10
# 583  06-Jul-24    Mumbai      21              24   Rainy               -16
# 584  07-Jul-24    Mumbai      32               8   Rainy                -5
# 585  08-Jul-24    Mumbai      22              11   Rainy               -17
# 586  09-Jul-24    Mumbai      19              18   Rainy                -3
#
#      Rel Hum %  Visibility_km  Press_kPa
# ...

# %%
df.rename(columns={'event':'Weather'}, inplace=True)
df
# Out:
#            day      city  Temp_C  windspeed_km/h Weather  Dew Point Temp_C  \
# 0    01-Nov-22  New York      22              19   Rainy               -12
# 1    02-Nov-22  New York      45              15   Sunny               -18
# 2    03-Nov-22  New York      40              16    Snow                -2
# 3    04-Nov-22  New York      41              16    Snow               -11
# 4    05-Nov-22    Mumbai      29               7   Rainy                -9
# ..         ...       ...     ...             ...     ...               ...
# 582  05-Jul-24    Mumbai      42              30   Rainy               -10
# 583  06-Jul-24    Mumbai      21              24   Rainy               -16
# 584  07-Jul-24    Mumbai      32               8   Rainy                -5
# 585  08-Jul-24    Mumbai      22              11   Rainy               -17
# 586  09-Jul-24    Mumbai      19              18   Rainy                -3
#
#      Rel Hum %  Visibility_km  Press_kPa
# ...

# %% [markdown]
# # Statisfical Insighs

# %%
df.describe()
# Out:
#            Temp_C  windspeed_km/h  Dew Point Temp_C   Rel Hum %  \
# count  587.000000      587.000000        587.000000  587.000000
# mean    33.642249       19.388416        -11.758092   54.507666
# std      9.020348        7.478004          6.136342   18.158231
# min     18.000000        7.000000        -22.000000   23.000000
# 25%     26.000000       13.000000        -17.000000   39.000000
# 50%     34.000000       19.000000        -12.000000   54.000000
# 75%     41.500000       26.000000         -6.000000   70.500000
# max     48.000000       32.000000         -2.000000   85.000000
#
#        Visibility_km   Press_kPa
# count     587.000000  587.000000
# mean       17.359455   93.662692
# std         6.400613   11.055338
# min         7.000000   75.000000
# 25%        12.000000   84.000000
# 50%        17.000000   94.000000
# 75%        23.000000  103.000000
# max        28.000000  112.000000

# %%
df.describe().T
# Out:
#                   count       mean        std   min   25%   50%    75%    max
# Temp_C            587.0  33.642249   9.020348  18.0  26.0  34.0   41.5   48.0
# windspeed_km/h    587.0  19.388416   7.478004   7.0  13.0  19.0   26.0   32.0
# Dew Point Temp_C  587.0 -11.758092   6.136342 -22.0 -17.0 -12.0   -6.0   -2.0
# Rel Hum %         587.0  54.507666  18.158231  23.0  39.0  54.0   70.5   85.0
# Visibility_km     587.0  17.359455   6.400613   7.0  12.0  17.0   23.0   28.0
# Press_kPa         587.0  93.662692  11.055338  75.0  84.0  94.0  103.0  112.0

# %% [markdown]
# ### Column wise statistical insighs

# %%
df['Temp_C'].mean()  # mean of Temperature
# Out:
# 33.642248722316864

# %%
df['Temp_C'].std() # standard deviation of Temperature
# Out:
# 9.020347895912195

# %%
df['Temp_C'].var() # variance of Temperature
# Out:
# 81.36667616328758

# %%
df['Temp_C'].max()
# Out:
# 48

# %%
df['Temp_C'].min()
# Out:
# 18

# %% [markdown]
# # Find str format data

# %%
df['Weather'].str.contains('Rainy')  # Find Str format data
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 582     True
# 583     True
# 584     True
# 585     True
# 586     True
# Name: Weather, Length: 587, dtype: bool

# %%
df[df['Weather'].str.contains('Rainy')] # Converting str format data to dataFrmae
# Out:
#            day      city  Temp_C  windspeed_km/h Weather  Dew Point Temp_C  \
# 0    01-Nov-22  New York      22              19   Rainy               -12
# 4    05-Nov-22    Mumbai      29               7   Rainy                -9
# 5    06-Nov-22    Mumbai      36              18   Rainy               -17
# 8    09-Nov-22     Paris      34              26   Rainy               -17
# 9    10-Nov-22     Paris      30              12   Rainy                -2
# ..         ...       ...     ...             ...     ...               ...
# 582  05-Jul-24    Mumbai      42              30   Rainy               -10
# 583  06-Jul-24    Mumbai      21              24   Rainy               -16
# 584  07-Jul-24    Mumbai      32               8   Rainy                -5
# 585  08-Jul-24    Mumbai      22              11   Rainy               -17
# 586  09-Jul-24    Mumbai      19              18   Rainy                -3
#
#      Rel Hum %  Visibility_km  Press_kPa
# ...

# %%
df[df['Weather'].str.contains('Rainy')].tail(5)
# Out:
#            day    city  Temp_C  windspeed_km/h Weather  Dew Point Temp_C  \
# 582  05-Jul-24  Mumbai      42              30   Rainy               -10
# 583  06-Jul-24  Mumbai      21              24   Rainy               -16
# 584  07-Jul-24  Mumbai      32               8   Rainy                -5
# 585  08-Jul-24  Mumbai      22              11   Rainy               -17
# 586  09-Jul-24  Mumbai      19              18   Rainy                -3
#
#      Rel Hum %  Visibility_km  Press_kPa
# 582         74             22         80
# 583         79             14        108
# 584         62             20        112
# 585         25             11        100
# 586         70             16         98

# %% [markdown]
# # Conditions

# %%
(df['windspeed_km/h']>24) & (df['Visibility_km']>9)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 582     True
# 583    False
# 584    False
# 585    False
# 586    False
# Length: 587, dtype: bool

# %%
df[(df['windspeed_km/h']>24) & (df['Visibility_km']>9)]  # Converting Data frame
# Out:
#            day    city  Temp_C  windspeed_km/h Weather  Dew Point Temp_C  \
# 10   11-Nov-22   Paris      33              32    Snow                -5
# 12   13-Nov-22   Paris      41              27    Snow               -18
# 15   16-Nov-22  Mumbai      25              31    Snow                -2
# 22   23-Nov-22  Mumbai      43              31    Snow               -21
# 25   26-Nov-22   Paris      22              27   Rainy                -3
# ..         ...     ...     ...             ...     ...               ...
# 565  18-Jun-24  Mumbai      35              25   Rainy               -15
# 567  20-Jun-24  Mumbai      25              30   Rainy               -18
# 569  22-Jun-24  Mumbai      31              31   Rainy               -15
# 577  30-Jun-24  Mumbai      42              30   Rainy               -10
# 582  05-Jul-24  Mumbai      42              30   Rainy               -10
#
#      Rel Hum %  Visibility_km  Press_kPa
# 10          68             22        110
# ...

# %% [markdown]
# # Group By

# %%
df.groupby('Weather') # Group by object created

# %%
df.groupby('Weather').mean()  # Data sorted as per Weather condtion mean
# Out:
#             Temp_C  windspeed_km/h  Dew Point Temp_C  Rel Hum %  \
# Weather
# Rainy    33.766854       19.477528        -11.924157  53.907303
# Snow     34.016129       19.701613        -10.967742  57.717742
# Sunny    32.794393       18.728972        -12.121495  52.785047
#
#          Visibility_km  Press_kPa
# Weather
# Rainy        17.275281  93.289326
# Snow         18.056452  94.064516
# Sunny        16.831776  94.439252

# %%
df.groupby('Weather').max() # Data sorted as per Weather condtion MAX
# Out:
#                day   city  Temp_C  windspeed_km/h  Dew Point Temp_C  \
# Weather
# Rainy    31-Oct-23  Paris      48              32                -2
# Snow     31-May-23  Paris      48              32                -2
# Sunny    31-Jan-23  Paris      48              32                -2
#
#          Rel Hum %  Visibility_km  Press_kPa
# Weather
# Rainy           85             28        112
# Snow            84             28        112
# Sunny           84             28        112

# %%
df.groupby('Weather').min() # Data sorted as per Weather condtion MIN
# Out:
#                day    city  Temp_C  windspeed_km/h  Dew Point Temp_C  \
# Weather
# Rainy    01-Apr-24  Mumbai      18               7               -22
# Snow     01-Apr-23  Mumbai      18               7               -22
# Sunny    01-Jan-23  Mumbai      18               7               -22
#
#          Rel Hum %  Visibility_km  Press_kPa
# Weather
# Rainy           23              7         75
# Snow            24              7         75
# Sunny           23              7         75

# %% [markdown]
# # OR Function / Pipe Operator

# %% [markdown]
# - Or/ pipe function returns when match any
# - Condition: Find value for eihter "Rainy" OR visibility > 80

# %%
(df['Weather']=='Rainy') | (df['Visibility_km']>80)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 582     True
# 583     True
# 584     True
# 585     True
# 586     True
# Length: 587, dtype: bool

# %%
df[(df['Weather']=='Rainy') | (df['Visibility_km']>80)]  # Data Frame Conversion
# Out:
#            day      city  Temp_C  windspeed_km/h Weather  Dew Point Temp_C  \
# 0    01-Nov-22  New York      22              19   Rainy               -12
# 4    05-Nov-22    Mumbai      29               7   Rainy                -9
# 5    06-Nov-22    Mumbai      36              18   Rainy               -17
# 8    09-Nov-22     Paris      34              26   Rainy               -17
# 9    10-Nov-22     Paris      30              12   Rainy                -2
# ..         ...       ...     ...             ...     ...               ...
# 582  05-Jul-24    Mumbai      42              30   Rainy               -10
# 583  06-Jul-24    Mumbai      21              24   Rainy               -16
# 584  07-Jul-24    Mumbai      32               8   Rainy                -5
# 585  08-Jul-24    Mumbai      22              11   Rainy               -17
# 586  09-Jul-24    Mumbai      19              18   Rainy                -3
#
#      Rel Hum %  Visibility_km  Press_kPa
# ...

# %%
df[(df['city']=='Paris') | (df['Weather']=='Rainy')]  # Return either Paris or Rainy
# Out:
#            day      city  Temp_C  windspeed_km/h Weather  Dew Point Temp_C  \
# 0    01-Nov-22  New York      22              19   Rainy               -12
# 4    05-Nov-22    Mumbai      29               7   Rainy                -9
# 5    06-Nov-22    Mumbai      36              18   Rainy               -17
# 8    09-Nov-22     Paris      34              26   Rainy               -17
# 9    10-Nov-22     Paris      30              12   Rainy                -2
# ..         ...       ...     ...             ...     ...               ...
# 582  05-Jul-24    Mumbai      42              30   Rainy               -10
# 583  06-Jul-24    Mumbai      21              24   Rainy               -16
# 584  07-Jul-24    Mumbai      32               8   Rainy                -5
# 585  08-Jul-24    Mumbai      22              11   Rainy               -17
# 586  09-Jul-24    Mumbai      19              18   Rainy                -3
#
#      Rel Hum %  Visibility_km  Press_kPa
# ...

# %% [markdown]
# ## And Condtions

# %% [markdown]
# - Multiple conditons (as long as you want) can be added by using & operator
# - All condtions must be matched or satisfy individually

# %%
(df['Weather']=='Rainy') & (df['Rel Hum %']>30) & (df['Visibility_km']>25)  # Three condions applied
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 582    False
# 583    False
# 584    False
# 585    False
# 586    False
# Length: 587, dtype: bool

# %%
df[(df['Weather']=='Rainy') & (df['Rel Hum %']>30) & (df['Visibility_km']>25)] # Data Frame
# Out:
#            day      city  Temp_C  windspeed_km/h Weather  Dew Point Temp_C  \
# 0    01-Nov-22  New York      22              19   Rainy               -12
# 41   12-Dec-22     Paris      46              32   Rainy               -11
# 48   19-Dec-22    Mumbai      46               9   Rainy                -2
# 77   17-Jan-23    Mumbai      35               8   Rainy               -16
# 127  07-Apr-23    Mumbai      35               7   Rainy                -2
# 128  08-Apr-23    Mumbai      44              22   Rainy                -3
# 141  21-Apr-23  New York      28              29   Rainy               -12
# 191  10-Jun-23    Mumbai      48              10   Rainy               -20
# 194  13-Jun-23     Paris      18              29   Rainy                -4
# 232  21-Jul-23     Paris      46              25   Rainy               -18
# 252  10-Aug-23    Mumbai      20               7   Rainy               -17
# ...
